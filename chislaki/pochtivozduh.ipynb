# %% [markdown]
# # Laba PZAD

# %% [markdown]
# ## slonyarniy setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

df = pd.read_csv("file.csv")
df
# Out:
#        Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0               0     17850.0      M  Chicago           12.0         16679.0
# 1               1     17850.0      M  Chicago           12.0         16680.0
# 2               2     17850.0      M  Chicago           12.0         16696.0
# 3               3     17850.0      M  Chicago           12.0         16699.0
# 4               4     17850.0      M  Chicago           12.0         16700.0
# ...           ...         ...    ...      ...            ...             ...
# 52950       52950         NaN    NaN      NaN            NaN             NaN
# 52951       52951         NaN    NaN      NaN            NaN             NaN
# 52952       52952         NaN    NaN      NaN            NaN             NaN
# 52953       52953         NaN    NaN      NaN            NaN             NaN
# 52954       52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# ...

# %%
df = df.drop(columns=["Unnamed: 0", "Gender", "Location", "Tenure_Months", "Product_SKU", "Product_Description", "Product_Category", "Delivery_Charges"])

# %%
df = df.drop(columns=["Month", "Coupon_Code", "Discount_pct"])
df
# Out:
#        CustomerID  Transaction_ID Transaction_Date  Quantity  Avg_Price  \
# 0         17850.0         16679.0       2019-01-01       1.0     153.71
# 1         17850.0         16680.0       2019-01-01       1.0     153.71
# 2         17850.0         16696.0       2019-01-01       2.0     122.77
# 3         17850.0         16699.0       2019-01-01       1.0      81.50
# 4         17850.0         16700.0       2019-01-01       1.0     153.71
# ...           ...             ...              ...       ...        ...
# 52950         NaN             NaN              NaN       NaN        NaN
# 52951         NaN             NaN              NaN       NaN        NaN
# 52952         NaN             NaN              NaN       NaN        NaN
# 52953         NaN             NaN              NaN       NaN        NaN
# 52954         NaN             NaN              NaN       NaN        NaN
#
#       Coupon_Status  GST      Date  Offline_Spend  Online_Spend
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        52924 non-null  float64
#  1   Transaction_ID    52924 non-null  float64
#  2   Transaction_Date  52924 non-null  object
#  3   Quantity          52924 non-null  float64
#  4   Avg_Price         52924 non-null  float64
#  5   Coupon_Status     52924 non-null  object
#  6   GST               52924 non-null  float64
#  7   Date              52924 non-null  object
#  8   Offline_Spend     52924 non-null  float64
#  9   Online_Spend      52924 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 4.0+ MB

# %%
import datetime

df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])
df.info()
df = df.drop(columns=["Coupon_Status", "GST", "Date"])
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        52924 non-null  float64
#  1   Transaction_ID    52924 non-null  float64
#  2   Transaction_Date  52924 non-null  datetime64[ns]
#  3   Quantity          52924 non-null  float64
#  4   Avg_Price         52924 non-null  float64
#  5   Coupon_Status     52924 non-null  object
#  6   GST               52924 non-null  float64
#  7   Date              52924 non-null  object
#  8   Offline_Spend     52924 non-null  float64
#  9   Online_Spend      52924 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(2)
# memory usage: 4.0+ MB
#        CustomerID  Transaction_ID Transaction_Date  Quantity  Avg_Price  \
# 0         17850.0         16679.0       2019-01-01       1.0     153.71
# ...

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52924 entries, 0 to 52923
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        52924 non-null  float64
#  1   Transaction_ID    52924 non-null  float64
#  2   Transaction_Date  52924 non-null  datetime64[ns]
#  3   Quantity          52924 non-null  float64
#  4   Avg_Price         52924 non-null  float64
#  5   Offline_Spend     52924 non-null  float64
#  6   Online_Spend      52924 non-null  float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 3.2 MB

# %%
df_2 = df.drop_duplicates(subset=['CustomerID', 'Transaction_Date'])
df_2 = df_2.reset_index()
df_2 = df_2.drop(columns="index")
df_2
# Out:
#       CustomerID  Transaction_ID Transaction_Date  Quantity  Avg_Price  \
# 0        17850.0         16679.0       2019-01-01       1.0     153.71
# 1        13047.0         16684.0       2019-01-01       2.0     122.77
# 2        12583.0         16694.0       2019-01-01       1.0     122.77
# 3        15100.0         16712.0       2019-01-01       1.0     153.71
# 4        14688.0         16732.0       2019-01-01       1.0     153.71
# ...          ...             ...              ...       ...        ...
# 3203     13481.0         23063.0       2019-03-16       1.0       2.80
# 3204     14901.0         24244.0       2019-03-27       1.0       2.80
# 3205     14344.0         23520.0       2019-03-20       1.0      22.99
# 3206     15498.0         23743.0       2019-03-21       5.0      17.59
# 3207     13777.0         25859.0       2019-04-18       1.0      50.00
#
#       Offline_Spend  Online_Spend
# 0            4500.0       2424.50
# 1            4500.0       2424.50
# ...

# %%
df_2["CustomerID"].value_counts()
# Out:
# CustomerID
# 12748.0    34
# 14606.0    27
# 14911.0    26
# 15311.0    24
# 17841.0    20
#            ..
# 15965.0     1
# 16086.0     1
# 16658.0     1
# 13030.0     1
# 14081.0     1
# Name: count, Length: 1468, dtype: int64

# %% [markdown]
# ## visits by all other slonyaras

# %%
visits = df_2.groupby('Transaction_Date')['CustomerID'].nunique()

plt.figure(figsize=(12, 4))
plt.plot(visits.index, visits.values)
plt.show()

# %% [markdown]
# ## top visits by slon visitor

# %%
top = df_2['CustomerID'].value_counts().head(1).index
top_visitdf = pd.DataFrame({'vozduh':df_2.loc[df_2['CustomerID'] == top.astype(float).item(), 'Transaction_Date'].to_list()})
sns.histplot(data=top_visitdf, x='vozduh', bins=30)
# Out:
# <Axes: xlabel='vozduh', ylabel='Count'>
